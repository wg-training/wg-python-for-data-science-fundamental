# %% [markdown]
# # Foundation Exercises

# %% [markdown]
# Create: a list of 3 elements: bread, milk, eggs
# Append 'butter' to the end of the list.
# Insert 'cheese' at index 1.
# Remove 'bread' from the list.
# Sort the list alphabetically.
# Print
# The list
#  and length of the list using len().

# %%
l = ["bread", "milk", "eggs"]

# %%
l.append("butter")
l
# Out:
# ['bread', 'milk', 'eggs', 'butter']

# %%
l.insert(1, "cheese")
l
# Out:
# ['bread', 'cheese', 'milk', 'eggs', 'butter']

# %%
# l.remove("bread")

# %%
l.pop(0)
# Out:
# 'bread'

# %%
print(l)
# Out:
# ['cheese', 'milk', 'eggs', 'butter']

# %%
l.sort()
print(l)
l.append("Egg")
# Out:
# ['Egg', 'butter', 'cheese', 'eggs', 'milk']

# %%
print(l)
# Out:
# ['Egg', 'butter', 'cheese', 'eggs', 'milk', 'Egg']

# %%
l.sort()
print(l)
# Out:
# ['Egg', 'Egg', 'butter', 'cheese', 'eggs', 'milk']

# %%
len(l)
# Out:
# 6

# %% [markdown]
# Create dictionary of {'title': 'Dune', 'author': 'Frank Herbert', 'year': 1965}
# Access the author using book['author'].
# Add a new key 'genre' with the value 'Sci-Fi'.
# Update the year to 2021 .
# Print: the dict.
# Print .keys() and .values().
# Remove the 'year' key.
# Print the dict again

# %%
book =  {'title': 'Dune', 'author': 'Frank Herbert', 'year': 1965}

# %%
book["author"]
# Out:
# 'Frank Herbert'

# %%
# book["genre"] = "Sci-Fi"
book_dict = { "genre": "Sci-Fi", "year": 2022}
book.update(book_dict)

# %%
book
# Out:
# {'title': 'Dune', 'author': 'Frank Herbert', 'year': 2022, 'genre': 'Sci-Fi'}

# %%
book["year"] = 2021
book["genre"] = "Literature"
book
# Out:
# {'title': 'Dune',
#  'author': 'Frank Herbert',
#  'year': 2021,
#  'genre': 'Literature'}

# %%
print(book.keys())
print(book.values())
# Out:
# dict_keys(['title', 'author', 'year', 'genre'])
# dict_values(['Dune', 'Frank Herbert', 2021, 'Literature'])

# %%
book.pop("year")
# Out:
# 2021

# %%
book
# Out:
# {'title': 'Dune', 'author': 'Frank Herbert', 'genre': 'Literature'}

# %% [markdown]
# Access the second movie using movies[1].
# Count how many times 'Inception' appears using .count().
# Find the index of 'Avatar' using .index().
# Print the length using len().

# %%
t = ("Inception", "Titanic", "Inception", "Avatar")
t
# Out:
# ('Inception', 'Titanic', 'Inception', 'Avatar')

# %%
t[1]
# Out:
# 'Titanic'

# %%
t.count("Inception")
# Out:
# 2

# %%
t.index("Avatar")
# Out:
# 3

# %%
len(t)
# Out:
# 4

# %%
len(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 len(4)
#
# TypeError: object of type 'int' has no len()

# %% [markdown]
# Add 'orange' to your_fruits.
# Find the union of your_fruits and friend_fruits, and print it.
# Find the intersection (fruits you both like).
# Find the difference (fruits only you like).
# Print the length of your_fruits using len().

# %%
your_fruits = { "apple", "banana", "mango" }
friend_fruits = {"banana", "kiwi", "grape"}

# %%
your_fruits.add("aorange")
your_fruits
# Out:
# {'aorange', 'apple', 'banana', 'mango', 'orange'}

# %%
your_fruits.union(friend_fruits)
# Out:
# {'aorange', 'apple', 'banana', 'grape', 'kiwi', 'mango', 'orange'}

# %%
your_fruits.intersection(friend_fruits)
# Out:
# {'banana'}

# %%
your_fruits.difference(friend_fruits)
# Out:
# {'aorange', 'apple', 'mango', 'orange'}

# %%
your_fruits.discard("apple")

# %%
your_fruits
# Out:
# {'aorange', 'banana', 'mango', 'orange'}

# %% [markdown]
# # Practices Collection method

# %%
ls = [
    1,
    2,
    3,4
    
]
ls
# Out:
# [1, 2, 3, 4]

# %%
groceries = [
    'bread',
    "milk", 
    """eg
    
    
    g"""
]

# TODO: append, insert at 1, print + len()
groceries.append("butter")
groceries.insert(1, "cheese")
print(groceries)
print(len(groceries))
# Out:
# ['bread', 'cheese', 'milk', 'eg\n\n\n    g', 'butter']
# 5

# %%
print(groceries[3])
# Out:
# eg
#
#
#     g

# %%
scores = [88, 72, 95, 60, 83]

# %%
scores.sort()
scores
# Out:
# [60, 72, 83, 88, 95]

# %%
scores.reverse()
score

# %%
movies = ('Inception', 'Avatar',
          'Inception', 'Titanic')

# TODO: count + index, print both
movies.count("Inception")
# Out:
# 2

# %%
movies.index("Avatar")
# Out:
# 1

# %%
point = (10, 25, 50)
point[0] + point[2]
# Out:
# 60

# %%
student = {'name': 'Alice', 'age': 20,
           'major': 'CS'}

# TODO: print name, add gpa, .get scholarship

print(student["name"])
# Out:
# Alice

# %%
student["gpa"] = 3.8
student
# Out:
# {'name': 'Alice', 'age': 20, 'major': 'CS', 'gpa': 3.8}

# %%
student["gpa"]
# Out:
# 3.8

# %%
student
# Out:
# {'name': 'Alice', 'age': 20, 'major': 'CS', 'gpa': 3.8}

# %%
student["Scholarship"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 student["Scholarship"]
#
# KeyError: 'Scholarship'

# %%
if "Scholarship" in student:
    print(student["Scholarship"])
else:
    print("NO")
# Out:
# Yes

# %%
student.get("Scholarship", "No")
# Out:
# 'No'

# %%
student["Scholarship"] = "100%"

# %%
student
# Out:
# {'name': 'Alice', 'age': 20, 'major': 'CS', 'gpa': 3.8, 'Scholarship': '100%'}

# %%
student.get("Scholarship", "No")
# Out:
# '100%'

# %%
prices = {'apple': 1.2, 'banana': 0.5,
          'orange': 0.8}

# TODO: update, pop, print keys()

prices.update({ "apple": 1.5})
print(prices)
prices.pop("banana")
print(prices)
print(prices.keys())
# Out:
# {'apple': 1.5, 'banana': 0.5, 'orange': 0.8}
# {'apple': 1.5, 'orange': 0.8}
# dict_keys(['apple', 'orange'])

# %%
colors = {'red', 'blue', 'green'}

# TODO: add, discard, print set + count
print(colors)
colors.add("red")
print(colors)
# Out:
# {'green', 'blue', 'red'}
# {'green', 'blue', 'red'}

# %%
colors.discard("blue")
print(colors)
# Out:
# {'green', 'red'}

# %%
art_club   = {'Alice', 'Bob', 'Charlie'}
drama_club = {'Bob', 'David', 'Charlie'}

# TODO: intersection, union

art_club.intersection(drama_club)
# Out:
# {'Bob', 'Charlie'}

# %%
art_club.union(drama_club)
# Out:
# {'Alice', 'Bob', 'Charlie', 'David'}
