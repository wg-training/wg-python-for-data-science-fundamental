# %% [markdown]
# # Arithmetic Operators

# %%
n1 = 10
n2 = 3

n1 // n2
# Out:
# 3

# %%
n1 % n2
# Out:
# 1

# %%
n1 ** n2
# Out:
# 1000

# %%
str1 = "hello"
str2 = "world"
str1 +str2
# Out:
# 'helloworld'

# %%
print(str1 + " " + str2)
str3 = "!"
# Out:
# hello world

# %%
str1*5
# Out:
# 'hellohellohellohellohello'

# %%
5 * str1
# Out:
# 'hellohellohellohellohello'

# %%
str(5) + str1
# Out:
# '5hello'

# %% [markdown]
# # String Methods

# %%
string = " Python is Pragramming Language"
string
# Out:
# ' Python is Pragramming Language'

# %%
string.upper()
# Out:
# ' PYTHON IS PRAGRAMMING LANGUAGE'

# %%
string.lower()
# Out:
# ' python is pragramming language'

# %%
string.strip()
# Out:
# 'Python is Pragramming Language'

# %%
string.replace("P", "J").replace("y", "i").upper()
# Out:
# ' JITHON IS JRAGRAMMING LANGUAGE'

# %%
v1 = string.replace("P", "J")
v2 =  v1.replace("y", "i")
v3 =  v2.upper()
print(v3)
# Out:
#  JITHON IS JRAGRAMMING LANGUAGE

# %% [markdown]
# # Slicing and Indexing

# %% [markdown]
# ## Indexing

# %%
string = "Python code!"

# %%
string[0]
# Out:
# 'P'

# %%
string[1]
# Out:
# 'y'

# %%
string[-1]
# Out:
# '!'

# %%
string[-2]
# Out:
# 'e'

# %% [markdown]
# ## Slicing

# %%
string = "Python code!"
string[0:6] # end is exclusive
# Out:
# 'Python'

# %%
string = "Python code!"
string[6:]
# Out:
# ' code!'

# %%
string[:6]
# Out:
# 'Python'

# %%
number ='0123456789'

# %%
number[:6]
# Out:
# '012345'

# %%
number[6:]
# Out:
# '6789'

# %%
number[6]
# Out:
# '6'

# %% [markdown]
# **Step**

# %%
number
# Out:
# '0123456789'

# %%
number[:6]
# Out:
# '012345'

# %%
number[:6:2]
# Out:
# '024'

# %%
number[1:6:2]
# Out:
# '135'

# %%
number[0:6:2]
# Out:
# '024'

# %%
id_number ='123456789abcdefgh'
id_number2 = '12ាសដថងហ្កល'
id_number3 = '12jdkjgdfklgjdklfgjdf'

# %%
id_number[0:2]
# Out:
# '12'

# %%
id_number2[0:2]
# Out:
# '12'

# %%
id_number3.startswith("12")
# Out:
# True

# %% [markdown]
# ### negative slicing

# %%
number = '0123456789'

# %%
number[-3:]
# Out:
# '789'

# %%
number[-5:-3]
# Out:
# '56'

# %%
number[-3:2:-1]
# Out:
# '76543'

# %%
number[2:-3:1]
# Out:
# '23456'
