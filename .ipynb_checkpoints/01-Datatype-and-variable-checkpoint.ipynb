# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # Data type

# %%
# int
1
# Out:
# 1

# %%
type(1)
# Out:
# int

# %%
# float
1.0
# Out:
# 1.0

# %%
type(1.0)
# Out:
# float

# %%
# String

# %%
'1'
# Out:
# '1'

# %%
"hello"
# Out:
# 'hello'

# %%
“hello”
# Out:
#   Cell In[10], line 1
#     “hello”
#     ^
# SyntaxError: invalid character '“' (U+201C)

# %%
type('1')
# Out:
# str

# %%
True
# Out:
# True

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
type('True')
# Out:
# str

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
None

# %%
type(' ')
# Out:
# str

# %%
10000000000000
# Out:
# 10000000000000

# %%
10_000_000_000_000
# Out:
# 10000000000000

# %%
10_000_000_000,1000
# Out:
# (10000000000, 1000)

# %% [markdown]
# # Variable

# %%
age = 30

# %%
print(age)
# Out:
# vengleab

# %%
age = "vengleab"

# %%
print(age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(age)
#
# NameError: name 'age' is not defined

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
print = 30

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
interest_rate = 0.1

# %%
Interest_rate = 0.2

# %%
print(interest_rate)
# Out:
# 0.1

# %%
print(Interest_rate)
# Out:
# 0.2

# %%
_rate = 0.3

# %%
$rate = 0.4
# Out:
#   Cell In[8], line 1
#     $rate = 0.4
#     ^
# SyntaxError: invalid syntax

# %%
rate2 = 0.5

# %%
rate$ =1
# Out:
#   Cell In[10], line 1
#     rate$ =1
#         ^
# SyntaxError: invalid syntax

# %%
2rate = 0.8
# Out:
#   Cell In[11], line 1
#     2rate = 0.8
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# # Data type conversion

# %%
value = 1

# %%
type(value)
# Out:
# int

# %%
value = str(value)

# %%
print(value)
# Out:
# 1

# %%
type(value)
# Out:
# str

# %%
value
# Out:
# '1'

# %%
value = float(value)
print(value)
# Out:
# 1.0

# %%
value = bool(value)
value
# Out:
# True

# %%
bool(value)
# Out:
# True

# %%
int(value)
# Out:
# 1

# %%
value
# Out:
# True

# %%
v1 = 1000
bool(v1)
# Out:
# True

# %%
v1
# Out:
# 1000

# %%
v1 = bool(v1)

# %%
v1
# Out:
# True

# %%
int(v1)
# Out:
# 1

# %%
int('1.99999')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 int('1.99999')
#
# ValueError: invalid literal for int() with base 10: '1.99999'

# %%
int(float("1.99999"))
# Out:
# 1
