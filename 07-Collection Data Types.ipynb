# %% [markdown]
# # List

# %%
mixed_list = [1, "Apple", True]

# %%
print(mixed_list.append("Manago"))
# Out:
# None

# %%
mixed_list
# Out:
# [1, 'Apple', True, 'Manago', 'Manago', 'Manago']

# %%
mixed_list[0:3]
# Out:
# [1, 'Apple', True]

# %%
mixed_list
# Out:
# [1, 'Apple', True, 'Manago', 'Manago', 'Manago']

# %%
mixed_list[::-1]
# Out:
# ['Manago', 'Manago', 'Manago', True, 'Apple', 1]

# %%
# List common methods

# %%
mixed_list
# Out:
# [1, 'Apple', True, 'Manago', 'Manago', 'Manago']

# %%
mixed_list.remove("Manago")
mixed_list
# Out:
# [1, 'Apple', True, 'Manago', 'Manago']

# %%
mixed_list.insert(0, "Manago")

# %%
mixed_list
# Out:
# ['Manago', 1, 'Apple', True, 'Manago', 'Manago']

# %%
mixed_list.remove("Manago")

# %%
mixed_list
# Out:
# [1, 'Apple', True, 'Manago', 'Manago']

# %%
mixed_list.remove('Mango')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 mixed_list.remove('Mango')
#
# ValueError: list.remove(x): x not in list

# %%
mixed_list.insert(1000,"Sixth value")

# %%
mixed_list
# Out:
# [1, 'Apple', True, 'Manago', 'Manago', 'Sixth value', 'Sixth value']

# %%
mixed_list[6]
# Out:
# 'Sixth value'

# %%
mixed_list[5]
# Out:
# 'Sixth value'

# %%
mixed_list
# Out:
# [1, 'Apple', True, 'Manago', 'Manago', 'Sixth value', 'Sixth value']

# %%
mixed_list.pop(0)
# Out:
# 1

# %%
mixed_list.pop(0)
# Out:
# 'Apple'

# %%
mixed_list
# Out:
# [True, 'Manago', 'Manago', 'Sixth value', 'Sixth value']

# %% [markdown]
# # Dict

# %%
person = { "name":"Chirst", "age": 25  }
person
# Out:
# {'name': 'Chirst', 'age': 25}

# %%
person["name"]
# Out:
# 'Chirst'

# %%
person["Name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 person["Name"]
#
# KeyError: 'Name'

# %%
person.get("Name")

# %%
person.get("name")
# Out:
# 'Chirst'

# %%
person.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
person.values()
# Out:
# dict_values(['Chirst', 25])

# %%
person.items()
# Out:
# dict_items([('name', 'Chirst'), ('age', 25)])

# %%
person.items()
# Out:
# dict_items([('name', 'Chirst'), ('age', 25)])

# %%
person
# Out:
# {'name': 'Chirst', 'age': 25}

# %%
person.update({'dob': '1990/01/01', "age1": 30})
print(person)
# Out:
# {'name': 'Chirst', 'age': 30, 'dob': '1990/01/01', 'age1': 30}

# %%
person["age"]
# Out:
# 30

# %%
person["age"]=31
person
# Out:
# {'name': 'Chirst', 'age': 31, 'dob': '1990/01/01', 'age1': 30}

# %%
person["age22222"]=31
person
# Out:
# {'name': 'Chirst', 'age': 31, 'dob': '1990/01/01', 'age1': 30, 'age22222': 31}

# %%
person.pop("age22222")
# Out:
# 31

# %%
person
# Out:
# {'name': 'Chirst', 'age': 31, 'dob': '1990/01/01', 'age1': 30}

# %%
person.clear()
print(person)
# Out:
# {}

# %%
person["transaction"] = [1,2,3,4,5]
person
# Out:
# {'transaction': [1, 2, 3, 4, 5]}

# %%
person.pop("transaction")
# Out:
# [1, 2, 3, 4, 5]

# %%
print(person)
# Out:
# {}

# %%
person["address"] = {"house_no": 70, "street": 480}
print(person)
# Out:
# {'address': {'house_no': 70, 'street': 480}}

# %%
person[0] = 1000

# %%
person
# Out:
# {'address': {'house_no': 70, 'street': 480}, 0: 1000}

# %% [markdown]
# # Tuple

# %%
numbers = (1,2,3,4,5)
print(numbers)
# Out:
# (1, 2, 3, 4, 5)

# %%
numbers[0]
# Out:
# 1

# %%
numbers[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 numbers[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
numbers = (1, 2)
numbers
# Out:
# (1, 2)

# %%
type(numbers)
# Out:
# tuple

# %%
numbers.count(2)
# Out:
# 1

# %%
animals = ["cat", "cat", "dog"]

# %%
animals.count("cat")
# Out:
# 2

# %%
animals.index("dog")
# Out:
# 2

# %%
len(animals)
# Out:
# 3

# %%
animals.len()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 animals.len()
#
# AttributeError: 'list' object has no attribute 'len'

# %%
numbers = (1,2,3,45)
#numbers = 90

# %%
type(numbers)
# Out:
# tuple

# %% [markdown]
# # Set

# %%
fruit = {"apple", "banana","orange"}
fruit
# Out:
# {'apple', 'banana', 'orange'}

# %%
fruit.add("lemon")

# %%
fruit
# Out:
# {'apple', 'banana', 'lemon', 'orange'}

# %%
fruit.add("lemon")
fruit
# Out:
# {'apple', 'banana', 'lemon', 'orange'}

# %%
animals = {"cat", "cat"}

# %%
animals.remove("cat")

# %%
animals
# Out:
# set()

# %%
fruit = {"apple", "banana","orange"}
fruit
# Out:
# {'apple', 'banana', 'orange'}

# %%
fruit.add("apple1")
fruit
# Out:
# {'apple', 'apple1', 'banana', 'orange'}

# %%
fruit.remove("appple1")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 fruit.remove("appple1")
#
# KeyError: 'appple1'

# %%
fruit.discard("appple1")

# %%
fruit
# Out:
# {'apple', 'apple1', 'banana', 'orange'}

# %%
fruit.remove("apple1")

# %%
fruit
# Out:
# {'apple', 'banana', 'orange'}

# %%
fruit.pop()
# Out:
# 'apple'

# %%
fruit
# Out:
# {'orange'}

# %%
fruit = {"apple", "banana","orange"}
fruit2 = {"orange", "lemon"}
print(fruit)
print(fruit2)
# Out:
# {'banana', 'apple', 'orange'}
# {'lemon', 'orange'}

# %%
fruit.union(fruit2)
# Out:
# {'apple', 'banana', 'lemon', 'orange'}

# %%
fruit.intersection(fruit2)
# Out:
# {'orange'}

# %%
fruit = {"apple", "banana","orange"}
fruit2 = {"orange", "lemon"}
print(fruit)
print(fruit2)
fruit.difference(fruit2)
# Out:
# {'banana', 'apple', 'orange'}
# {'lemon', 'orange'}
# {'apple', 'banana'}

# %%
fruit2.difference(fruit)
# Out:
# {'lemon'}
